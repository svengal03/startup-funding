# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns
df=pd.read_csv('/Users/krishna/Desktop/project/sf.csv')
df.head(5)
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# ...

# %%
df.dtypes
# Out:
# SNo                  int64
# Date                object
# StartupName         object
# IndustryVertical    object
# SubVertical         object
# CityLocation        object
# InvestorsName       object
# InvestmentType      object
# AmountInUSD         object
# Remarks             object
# dtype: object

# %%
top = df["InvestmentType"].value_counts()
top.sort_values(ascending=False)
top = top[:10]
top.plot(kind="bar")

# %%
df.shape
# Out:
# (2372, 10)

# %%
df.describe()
# Out:
#                SNo
# count  2372.000000
# mean   1185.500000
# std     684.881742
# min       0.000000
# 25%     592.750000
# 50%    1185.500000
# 75%    1778.250000
# max    2371.000000

# %%
df.AmountInUSD.unique()
# Out:
# array(['1,300,000', nan, '500,000', '850,000', '1,000,000', '2,600,000',
#        '20,000,000', '8,500,000', '12,000,000', '3,000,000', '2,250,000',
#        '464,000', '18,500,000', '540,000', '1,700,000', '2,000,000',
#        '4,000,000', '10,000,000', '600,000', '700,000', '200,000',
#        '1,200,000', '35,000,000', '25,000,000', '15,000,000', '1,250,000',
#        '50,000,000', '650,000', '232,000', '1,500,000', '350,000',
#        '300,000', '250,000', '7,800,000', '776,000', '5,500,000',
#        '12,300,000', '100,000', '12,500,000', '5,200,000', '2,400,000',
#        '4,500,000', '215,000', '31,000,000', '4,600,000', '5,000,000',
#        '71,000,000', '311,000', '21,000,000', '73,700,000', '390,000',
#        '104,500,000', '233,000', '50,000', '1,400,000', '7,700,000',
#        '466,000', '5,300,000', '1,400,000,000', '30,000,000', '6,600,000',
#        '580,000', '8,000,000', '3,500,000', '80,000,000', '7,000,000',
# ...

# %%
def startupmap(x):
    if x == "":
        return 1
    else:
        return 0

df['mappedvalue'] = df.SubVertical.apply(startupmap)

df.mappedvalue.value_counts()
# Out:
# 0    2372
# Name: mappedvalue, dtype: int64

# %%
df.CityLocation.value_counts()
# Out:
# Bangalore                 627
# Mumbai                    446
# New Delhi                 381
# Gurgaon                   240
# Pune                       84
# Noida                      78
# Hyderabad                  76
# Chennai                    66
# Ahmedabad                  35
# Jaipur                     25
# Kolkata                    19
# Chandigarh                 10
# Vadodara                    9
# Indore                      9
# Goa                         7
# Singapore                   5
# Delhi                       4
# Kanpur                      4
# Pune / US                   4
# Coimbatore                  3
# Trivandrum                  2
# Bangalore / SFO             2
# Gwalior                     2
# Siliguri                    2
# Kochi                       2
# Bangalore/ Bangkok          2
# Udupi                       2
# Bhopal                      2
# New Delhi / US              2
# Agra                        2
#                          ...
# ...

# %%
top = df["CityLocation"].value_counts()
top.sort_values(ascending=False)
top = top[:10]
top.plot(kind="bar")

# %%
df.isnull().sum().sort_values(ascending =False)
# Out:
# Remarks             1953
# SubVertical          936
# AmountInUSD          847
# CityLocation         179
# IndustryVertical     171
# InvestorsName          8
# InvestmentType         1
# mappedvalue            0
# StartupName            0
# Date                   0
# SNo                    0
# dtype: int64

# %%
missing=df.isnull().sum().sort_values(ascending =False)
percent = (missing/df.isnull().count())*100
print("Percentage of missing data")
percent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f7e051304b55> in <module>()
# ----> 1 missing=df.isnull().sum().sort_values(ascending =False)
#
# NameError: name 'df' is not defined

# %%
df.drop(['Remarks'],axis=1)
# Out:
#        SNo         Date       StartupName   IndustryVertical  \
# 0        0   01/08/2017          TouchKin         Technology
# 1        1   02/08/2017           Ethinos         Technology
# 2        2   02/08/2017      Leverage Edu  Consumer Internet
# 3        3   02/08/2017              Zepo  Consumer Internet
# 4        4   02/08/2017      Click2Clinic  Consumer Internet
# 5        5   01/07/2017     Billion Loans  Consumer Internet
# 6        6   03/07/2017  Ecolibriumenergy         Technology
# 7        7   04/07/2017             Droom          eCommerce
# 8        8   05/07/2017         Jumbotail          eCommerce
# 9        9   05/07/2017            Moglix          eCommerce
# 10      10   05/07/2017        Timesaverz  Consumer Internet
# 11      11   06/07/2017            Minjar         Technology
# 12      12   06/07/2017       MyCity4kids  Consumer Internet
# 13      13   07/07/2017          Clip App  Consumer Internet
# ...

# %%
df.drop(['mappedvalue'],axis=1)
# Out:
#        SNo         Date       StartupName   IndustryVertical  \
# 0        0   01/08/2017          TouchKin         Technology
# 1        1   02/08/2017           Ethinos         Technology
# 2        2   02/08/2017      Leverage Edu  Consumer Internet
# 3        3   02/08/2017              Zepo  Consumer Internet
# 4        4   02/08/2017      Click2Clinic  Consumer Internet
# 5        5   01/07/2017     Billion Loans  Consumer Internet
# 6        6   03/07/2017  Ecolibriumenergy         Technology
# 7        7   04/07/2017             Droom          eCommerce
# 8        8   05/07/2017         Jumbotail          eCommerce
# 9        9   05/07/2017            Moglix          eCommerce
# 10      10   05/07/2017        Timesaverz  Consumer Internet
# 11      11   06/07/2017            Minjar         Technology
# 12      12   06/07/2017       MyCity4kids  Consumer Internet
# 13      13   07/07/2017          Clip App  Consumer Internet
# ...

# %%
df.drop(['Remarks'],axis=1)
# Out:
#        SNo         Date       StartupName   IndustryVertical  \
# 0        0   01/08/2017          TouchKin         Technology
# 1        1   02/08/2017           Ethinos         Technology
# 2        2   02/08/2017      Leverage Edu  Consumer Internet
# 3        3   02/08/2017              Zepo  Consumer Internet
# 4        4   02/08/2017      Click2Clinic  Consumer Internet
# 5        5   01/07/2017     Billion Loans  Consumer Internet
# 6        6   03/07/2017  Ecolibriumenergy         Technology
# 7        7   04/07/2017             Droom          eCommerce
# 8        8   05/07/2017         Jumbotail          eCommerce
# 9        9   05/07/2017            Moglix          eCommerce
# 10      10   05/07/2017        Timesaverz  Consumer Internet
# 11      11   06/07/2017            Minjar         Technology
# 12      12   06/07/2017       MyCity4kids  Consumer Internet
# 13      13   07/07/2017          Clip App  Consumer Internet
# ...

# %%
df['AmountInUSD'] = df['AmountInUSD'].apply(lambda x:float(str(x).replace(",","")))
# Out:
# Minimum Investment
# 16000.0

# %%
df['AmountInUSD'].max()
# Out:
# 1400000000.0

# %%
df['AmountInUSD'].mean()
# Out:
# 12031073.099016393

# %%
df[df['AmountInUSD']==1400000000]
# Out:
#      SNo        Date StartupName IndustryVertical  \
# 158  158  18/05/2017       Paytm        ECommerce
# 294  294  21/03/2017    Flipkart        eCommerce
#
#                             SubVertical CityLocation  \
# 158  Mobile Wallet & ECommerce platform    Bangalore
# 294               ECommerce Marketplace    Bangalore
#
#                          InvestorsName  InvestmentType   AmountInUSD Remarks  \
# 158                     SoftBank Group  Private Equity  1.400000e+09     NaN
# 294  Microsoft, eBay, Tencent Holdings  Private Equity  1.400000e+09     NaN
#
#      mappedvalue
# 158            0
# 294            0

# %%
df['Date']=df['Date'].replace({"12/05.2015":"12/05/2015"})
df['Date']=df['Date'].replace({"13/04.2015":"13/04/2015"})
df['Date']=df['Date'].replace({"15/01.2015":"15/01/2015"})
df['Date']=df['Date'].replace({"22/01//2015":"22/01/2015"})

# %%
df["ipm"] = (pd.to_datetime(df['Date'],format='%d/%m/%Y').dt.month)+(pd.to_datetime(df['Date'],format='%d/%m/%Y').dt.year*100)
temp = df['ipm'].value_counts().sort_values(ascending = False)
print("Number of funding per month in decreasing order (Funding Wise)\n\n",temp)
year_month = df['ipm'].value_counts()
# Out:
# Number of funding per month in decreasing order (Funding Wise)
#
#  201601    104
# 201602    100
# 201606     98
# 201508     98
# 201507     98
# 201510     93
# 201511     92
# 201512     89
# 201509     88
# 201608     87
# 201506     86
# 201603     85
# 201610     80
# 201604     79
# 201605     79
# 201609     73
# 201612     72
# 201611     72
# 201701     72
# 201704     71
# 201703     71
# 201705     68
# 201706     65
# 201607     64
# 201504     63
# 201505     61
# 201503     60
# 201502     55
# 201501     53
# 201702     48
# 201707     43
# 201708      5
# Name: ipm, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot( df.ipm,df.AmountInUSD, alpha=0.9)
plt.xticks(rotation='vertical')
plt.xlabel('Year-Month', fontsize=12)
plt.ylabel('Amonut Of Investments', fontsize=12)
plt.title("YearMonth - Number of fundings distribution", fontsize=16)
plt.show()

# %%
tot = (df['StartupName'].value_counts()).values
c=0
for i in tot:
    if i > 1:
        c=c+1
print("Startups that got funding more than 1 times = ",c)
# Out:
# Startups that got funding more than 1 times =  281

# %%
fundcount  = df['StartupName'].value_counts()
fundcount = fundcount.head(20)
print(fundcount)
# Out:
# Swiggy           7
# UrbanClap        6
# Jugnoo           5
# Medinfi          5
# NoBroker         5
# Paytm            5
# Wooplr           4
# Tracxn           4
# TinyStep         4
# Capital Float    4
# YepMe            4
# HolaChef         4
# Voonik           4
# Flipkart         4
# Vyomo            4
# Ola              4
# Simplilearn      4
# Byju’s           4
# Niki.ai          4
# Ola Cabs         4
# Name: StartupName, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot(fundcount.index, fundcount.values, alpha=0.9)
plt.xticks(rotation='vertical')
plt.xlabel('Startups', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("Startups-Number of fundings distribution", fontsize=16)
plt.show()

# %%
IndustryVert = df['IndustryVertical'].value_counts().head(20)
print(IndustryVert)
# Out:
# Consumer Internet                772
# Technology                       313
# eCommerce                        171
# ECommerce                         53
# Healthcare                        30
# Logistics                         24
# Education                         20
# Food & Beverage                   19
# Finance                            9
# Others                             6
# Online Food Delivery               5
# Online Education Platform          5
# Real Estate                        4
# Logistics Tech                     3
# ecommerce                          3
# Big Data & Analytics platform      3
# FMCG                               3
# Hyperlocal Handyman Services       3
# Ecommerce                          3
# Food Delivery Platform             3
# Name: IndustryVertical, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot(IndustryVert.index, IndustryVert.values, alpha=0.9)
plt.xticks(rotation='vertical')
plt.xlabel('Industry Verticals', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("Industry Verticals-Number of fundings distribution", fontsize=16)
plt.show()

# %%
subvertical = df['SubVertical']
subvertical=subvertical.value_counts().head(25)
print(subvertical)
# Out:
# Online Pharmacy                           9
# Food Delivery Platform                    8
# Online lending platform                   5
# Online Learning Platform                  4
# ECommerce Marketplace                     3
# Data Analytics platform                   3
# Fitness Mobile App                        3
# Online Payment Gateway                    3
# Online Furniture Store                    2
# Online Tax Filing Platform                2
# Online learning platform                  2
# Online fashion rental platform            2
# Online Food Ordering & Delivery Portal    2
# Cab Aggregation App                       2
# Online marketplace                        2
# Food Ordering Mobile App                  2
# Online Doctor Consulting platform         2
# Medical Supplies eTailer                  2
# Online Gifting platform                   2
# Online Real Estate Portal                 2
# Fashion Apparel eTailer                   2
# ...

# %%
plt.figure(figsize=(15,8))
sns.barplot(subvertical.index, subvertical.values, alpha=0.9)
plt.xticks(rotation='vertical')
plt.xlabel('Industry Sub Verticals', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("Industry Sub Verticals-Number of fundings distribution", fontsize=16)
plt.show()

# %%
InvestmentType = df['InvestmentType'].value_counts()
print(InvestmentType)
# Out:
# Seed Funding      1271
# Private Equity    1066
# SeedFunding         30
# Crowd Funding        1
# Crowd funding        1
# Debt Funding         1
# PrivateEquity        1
# Name: InvestmentType, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(InvestmentType.index, InvestmentType.values, alpha=0.9)
plt.xticks(rotation='vertical')
plt.xlabel('Investment Type', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("Investment Type - Number of fundings distribution", fontsize=16)
plt.show()

# %%
df['CityLocation'].value_counts().head(10)
# Out:
# Bangalore    627
# Mumbai       446
# New Delhi    381
# Gurgaon      240
# Pune          84
# Noida         78
# Hyderabad     76
# Chennai       66
# Ahmedabad     35
# Jaipur        25
# Name: CityLocation, dtype: int64

# %%
fundcity = df['CityLocation'].value_counts()
plt.figure(figsize=(16,9))
sns.barplot(fundcity.index, fundcity.values, alpha=0.9)
plt.xticks(rotation='vertical')
plt.xlabel('City', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("City - Number of fundings distribution", fontsize=16)
plt.show()

# %%
df=df.dropna(subset=['IndustryVertical', 'AmountInUSD'])

# %%
df=df.dropna(subset=['SubVertical', 'AmountInUSD'])

# %%
df
# Out:
#        SNo        Date           StartupName   IndustryVertical  \
# 0        0  01/08/2017              TouchKin         Technology
# 3        3  02/08/2017                  Zepo  Consumer Internet
# 4        4  02/08/2017          Click2Clinic  Consumer Internet
# 5        5  01/07/2017         Billion Loans  Consumer Internet
# 6        6  03/07/2017      Ecolibriumenergy         Technology
# 7        7  04/07/2017                 Droom          eCommerce
# 8        8  05/07/2017             Jumbotail          eCommerce
# 9        9  05/07/2017                Moglix          eCommerce
# 10      10  05/07/2017            Timesaverz  Consumer Internet
# 13      13  07/07/2017              Clip App  Consumer Internet
# 15      15  10/07/2017            Autorox.co         Technology
# 16      16  11/07/2017                Fabogo  Consumer Internet
# 17      17  11/07/2017            Flickstree  Consumer Internet
# 19      19  12/07/2017              Innoviti         Technology
# ...

# %%
df=df.drop('Remarks', axis=1)

# %%
df=df.drop('ipm', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-2d9696af1e7c> in <module>()
# ----> 1 df=df.drop('ipm', axis=1)
#       2 df=df.drop('mappedvalue',axis=1)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# ...

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['InvestmentType'],df['AmountInUSD'])

# %%
df
# Out:
#        SNo        Date           StartupName   IndustryVertical  \
# 0        0  01/08/2017              TouchKin         Technology
# 3        3  02/08/2017                  Zepo  Consumer Internet
# 4        4  02/08/2017          Click2Clinic  Consumer Internet
# 5        5  01/07/2017         Billion Loans  Consumer Internet
# 6        6  03/07/2017      Ecolibriumenergy         Technology
# 7        7  04/07/2017                 Droom          eCommerce
# 8        8  05/07/2017             Jumbotail          eCommerce
# 9        9  05/07/2017                Moglix          eCommerce
# 10      10  05/07/2017            Timesaverz  Consumer Internet
# 13      13  07/07/2017              Clip App  Consumer Internet
# 15      15  10/07/2017            Autorox.co         Technology
# 16      16  11/07/2017                Fabogo  Consumer Internet
# 17      17  11/07/2017            Flickstree  Consumer Internet
# 19      19  12/07/2017              Innoviti         Technology
# ...

# %%
df=df.drop('mappedvalue',axis=1)

# %%
df
# Out:
#        SNo        Date           StartupName   IndustryVertical  \
# 0        0  01/08/2017              TouchKin         Technology
# 3        3  02/08/2017                  Zepo  Consumer Internet
# 4        4  02/08/2017          Click2Clinic  Consumer Internet
# 5        5  01/07/2017         Billion Loans  Consumer Internet
# 6        6  03/07/2017      Ecolibriumenergy         Technology
# 7        7  04/07/2017                 Droom          eCommerce
# 8        8  05/07/2017             Jumbotail          eCommerce
# 9        9  05/07/2017                Moglix          eCommerce
# 10      10  05/07/2017            Timesaverz  Consumer Internet
# 13      13  07/07/2017              Clip App  Consumer Internet
# 15      15  10/07/2017            Autorox.co         Technology
# 16      16  11/07/2017                Fabogo  Consumer Internet
# 17      17  11/07/2017            Flickstree  Consumer Internet
# 19      19  12/07/2017              Innoviti         Technology
# ...

# %%
df=df.drop('SNo',axis=1)

# %%
df=df.drop('Date',axis=1)

# %%
df=df.drop('InvestorsName',axis=1)

# %%
df=df.drop('StartupName',axis=1)

# %%
df
# Out:
#        IndustryVertical                                        SubVertical  \
# 0            Technology                           Predictive Care Platform
# 3     Consumer Internet                             DIY Ecommerce platform
# 4     Consumer Internet                      healthcare service aggregator
# 5     Consumer Internet                      Peer to Peer Lending platform
# 6            Technology               Energy management solutions provider
# 7             eCommerce                 Online marketplace for automobiles
# 8             eCommerce            online marketplace for food and grocery
# 9             eCommerce            B2B marketplace for Industrial products
# 10    Consumer Internet                  Hyperlocal home services provider
# 13    Consumer Internet                       Digital Media Video platform
# 15           Technology              Workshop Management Software Platform
# ...
