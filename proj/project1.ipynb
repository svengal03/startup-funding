# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns
df=pd.read_csv('/Users/krishna/Desktop/project/abc.csv')

# %%
df
# Out:
#                                IndustryVertical CityLocation  InvestmentType  \
# 0                                    Technology    Bangalore  Private Equity
# 1                             Consumer Internet       Mumbai    Seed Funding
# 2                             Consumer Internet    Hyderabad    Seed Funding
# 3                             Consumer Internet    Bangalore    Seed Funding
# 4                                    Technology    Ahmedabad  Private Equity
# 5                                     eCommerce      Gurgaon  Private Equity
# 6                                     eCommerce    Bangalore  Private Equity
# 7                             Consumer Internet       Mumbai  Private Equity
# 8                             Consumer Internet    Bangalore    Seed Funding
# 9                                    Technology    Hyderabad  Private Equity
# 10                            Consumer Internet       Mumbai    Seed Funding
# 11                                   Technology    Bangalore  Private Equity
# 12                                   Technology    Bangalore    Seed Funding
# 13                                    eCommerce    Bangalore  Private Equity
# 14                                   Technology    Bangalore    Seed Funding
# 15                            Consumer Internet    Bangalore  Private Equity
# 16                                   Technology    Bangalore    Seed Funding
# 17                                   Technology      Gurgaon    Seed Funding
# 18                                    eCommerce      Gurgaon    Seed Funding
# 19                            Consumer Internet    Bangalore  Private Equity
# 20                            Consumer Internet    Bangalore  Private Equity
# 21                            Consumer Internet    New Delhi  Private Equity
# 22                            Consumer Internet    Bangalore    Seed Funding
# 23                                    eCommerce      Gurgaon  Private Equity
# 24                            Consumer Internet       Mumbai  Private Equity
# 25                            Consumer Internet       Mumbai  Private Equity
# 26                                    eCommerce      Gurgaon  Private Equity
# 27                            Consumer Internet    Bangalore  Private Equity
# 28                            Consumer Internet    New Delhi    Seed Funding
# 29                            Consumer Internet    New Delhi    Seed Funding
# ..                                          ...          ...             ...
# 760          Healthcare IT Solutions & services      Chennai  Private Equity
# 761                   Online Logistics Platform    Bangalore  Private Equity
# 762                Hyperlocal Logistics Service    Bangalore  Private Equity
# 763       ECommerce Brands’ Full Service Agency       Mumbai    Seed Funding
# 764               End-to-end Logistics platform       Mumbai  Private Equity
# 765                ECommerce Logistics provider    New Delhi  Private Equity
# 766                On-Demand Delivery Logistics    New Delhi  Private Equity
# 767                     Logistics Tech Platform    Bangalore    Seed Funding
# 768                  Logistics service platform    Ahmedabad    Seed Funding
# 769                       Healthcare Mobile App    New Delhi  Private Equity
# 770                     Educational Board Games    Bangalore    Seed Funding
# 771  Probiotic Technology Products Manufacturer      Chennai  Private Equity
# 772                 Logistics Solution Provider    New Delhi  Private Equity
# 773                          eCommerce platform    Bangalore  Private Equity
# 774                  HealthcareService provider    Bangalore  Private Equity
# 775                  Global Healthcare products    Ahmedabad  Private Equity
# 776                Intra-City Logistics service    Bangalore    Seed Funding
# 777                              Logistics Tech       Mumbai  Private Equity
# 778                        Affordable Education    Hyderabad    Seed Funding
# 779                         Ecommerce Logistics      Gurgaon  Private Equity
# 780                   Online Education Platform       Mumbai  Private Equity
# 781                   Online Education Platform    Bangalore  Private Equity
# 782                   Online Education Platform       Mumbai    Seed Funding
# 783                         Last Mile Logistics    Bangalore    Seed Funding
# 784                  Online FurnishingeCommerce    Bangalore  Private Equity
# 785                              Logistics Tech       Mumbai    Seed Funding
# 786                           Fashion ECommerce    Bangalore  Private Equity
# 787                    Ethnic Product eCommerce       Mumbai  Private Equity
# 788                   Food Logistics & Delivery       Mumbai    Seed Funding
# 789                   Tele-Shopping / eCommerce       Mumbai  Private Equity
#
#      AmountInUSD
# 0        1300000
# 1         500000
# 2         850000
# 3        1000000
# 4        2600000
# 5       20000000
# 6        8500000
# 7        1000000
# 8        1000000
# 9        3000000
# 10        464000
# 11      18500000
# 12        540000
# 13       1700000
# 14       2000000
# 15      10000000
# 16        600000
# 17        700000
# 18        200000
# 19       1200000
# 20      35000000
# 21      25000000
# 22        200000
# 23      15000000
# 24       1250000
# 25      50000000
# 26       1000000
# 27       1200000
# 28       1000000
# 29        650000
# ..           ...
# 760     10000000
# 761      5000000
# 762     10000000
# 763       100000
# 764     10000000
# 765      5000000
# 766      1300000
# 767      1300000
# 768       245000
# 769     10200000
# 770       168000
# 771       550000
# 772    137000000
# 773     50000000
# 774     10000000
# 775     16000000
# 776       500000
# 777      5500000
# 778       650000
# 779     85000000
# 780     10000000
# 781      5000000
# 782      2000000
# 783       240000
# 784     50000000
# 785       500000
# 786      3500000
# 787     18000000
# 788      1000000
# 789     21500000
#
# [790 rows x 4 columns]

# %%
df.dtypes
# Out:
# IndustryVertical    object
# CityLocation        object
# InvestmentType      object
# AmountInUSD          int64
# dtype: object

# %%
IndustryVert = df['IndustryVertical'].value_counts().head(20)
print(IndustryVert)
# Out:
# Consumer Internet                         416
# Technology                                151
# eCommerce                                 101
# ECommerce                                  31
# Logistics                                  15
# Healthcare                                 11
# Education                                  11
# Food & Beverage                            10
# Online Education Platform                   3
# Logistics Tech Platform                     2
# Logistics Tech                              2
# eCommerce Product Search Engine             1
# Delivery & Logistics Service provider       1
# B2B eCommerce Marketplace                   1
# ECommerce Logistics provider                1
# Digital Healthcare                          1
# Global Healthcare products                  1
# Online Logistics Platform                   1
# Healthcare Services Discovery platform      1
# Last Mile Logistics                         1
# Name: IndustryVertical, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot(IndustryVert.index, IndustryVert.values, alpha=0.9)
plt.xticks(rotation='vertical')
plt.xlabel('Industry Verticals', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("Industry Verticals-Number of fundings distribution", fontsize=16)
plt.show()

# %%
InvestmentType = df['InvestmentType'].value_counts()
print(InvestmentType)
# Out:
# Private Equity    446
# Seed Funding      343
# Debt Funding        1
# Name: InvestmentType, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.barplot(InvestmentType.index, InvestmentType.values, alpha=0.9)
plt.xticks(rotation='vertical')
plt.xlabel('Investment Type', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("Investment Type - Number of fundings distribution", fontsize=16)
plt.show()

# %%
temp = df["InvestmentType"].value_counts()
labels = ['Seed Funding','Private Equity','Debt Funding']
sizes = (temp / temp.sum())*100
colors = ['gold', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

# %%
df['CityLocation'].value_counts().head(10)
# Out:
# Bangalore             278
# Mumbai                188
# New Delhi             135
# Gurgaon                99
# Hyderabad              35
# Chennai                31
# Ahmedabad              19
# New Delhi / US          1
# Bangalore/ Bangkok      1
# Mumbai / UK             1
# Name: CityLocation, dtype: int64

# %%
fundcity = df['CityLocation'].value_counts()
plt.figure(figsize=(16,9))
sns.barplot(fundcity.index, fundcity.values, alpha=0.9)
plt.xticks(rotation='vertical')
plt.xlabel('City', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("City - Number of fundings distribution", fontsize=16)
plt.show()

# %%
industries_vertical = df['IndustryVertical'].apply(lambda iv:str(iv).upper())
industries = industries_vertical.dropna().unique()[:10]
industries_count = industries_vertical.value_counts()[:10]

# %%
df
# Out:
#                                IndustryVertical CityLocation  InvestmentType  \
# 0                                    Technology    Bangalore  Private Equity
# 1                             Consumer Internet       Mumbai    Seed Funding
# 2                             Consumer Internet    Hyderabad    Seed Funding
# 3                             Consumer Internet    Bangalore    Seed Funding
# 4                                    Technology    Ahmedabad  Private Equity
# 5                                     eCommerce      Gurgaon  Private Equity
# 6                                     eCommerce    Bangalore  Private Equity
# 7                             Consumer Internet       Mumbai  Private Equity
# 8                             Consumer Internet    Bangalore    Seed Funding
# 9                                    Technology    Hyderabad  Private Equity
# 10                            Consumer Internet       Mumbai    Seed Funding
# 11                                   Technology    Bangalore  Private Equity
# 12                                   Technology    Bangalore    Seed Funding
# 13                                    eCommerce    Bangalore  Private Equity
# 14                                   Technology    Bangalore    Seed Funding
# 15                            Consumer Internet    Bangalore  Private Equity
# 16                                   Technology    Bangalore    Seed Funding
# 17                                   Technology      Gurgaon    Seed Funding
# 18                                    eCommerce      Gurgaon    Seed Funding
# 19                            Consumer Internet    Bangalore  Private Equity
# 20                            Consumer Internet    Bangalore  Private Equity
# 21                            Consumer Internet    New Delhi  Private Equity
# 22                            Consumer Internet    Bangalore    Seed Funding
# 23                                    eCommerce      Gurgaon  Private Equity
# 24                            Consumer Internet       Mumbai  Private Equity
# 25                            Consumer Internet       Mumbai  Private Equity
# 26                                    eCommerce      Gurgaon  Private Equity
# 27                            Consumer Internet    Bangalore  Private Equity
# 28                            Consumer Internet    New Delhi    Seed Funding
# 29                            Consumer Internet    New Delhi    Seed Funding
# ..                                          ...          ...             ...
# 760          Healthcare IT Solutions & services      Chennai  Private Equity
# 761                   Online Logistics Platform    Bangalore  Private Equity
# 762                Hyperlocal Logistics Service    Bangalore  Private Equity
# 763       ECommerce Brands’ Full Service Agency       Mumbai    Seed Funding
# 764               End-to-end Logistics platform       Mumbai  Private Equity
# 765                ECommerce Logistics provider    New Delhi  Private Equity
# 766                On-Demand Delivery Logistics    New Delhi  Private Equity
# 767                     Logistics Tech Platform    Bangalore    Seed Funding
# 768                  Logistics service platform    Ahmedabad    Seed Funding
# 769                       Healthcare Mobile App    New Delhi  Private Equity
# 770                     Educational Board Games    Bangalore    Seed Funding
# 771  Probiotic Technology Products Manufacturer      Chennai  Private Equity
# 772                 Logistics Solution Provider    New Delhi  Private Equity
# 773                          eCommerce platform    Bangalore  Private Equity
# 774                  HealthcareService provider    Bangalore  Private Equity
# 775                  Global Healthcare products    Ahmedabad  Private Equity
# 776                Intra-City Logistics service    Bangalore    Seed Funding
# 777                              Logistics Tech       Mumbai  Private Equity
# 778                        Affordable Education    Hyderabad    Seed Funding
# 779                         Ecommerce Logistics      Gurgaon  Private Equity
# 780                   Online Education Platform       Mumbai  Private Equity
# 781                   Online Education Platform    Bangalore  Private Equity
# 782                   Online Education Platform       Mumbai    Seed Funding
# 783                         Last Mile Logistics    Bangalore    Seed Funding
# 784                  Online FurnishingeCommerce    Bangalore  Private Equity
# 785                              Logistics Tech       Mumbai    Seed Funding
# 786                           Fashion ECommerce    Bangalore  Private Equity
# 787                    Ethnic Product eCommerce       Mumbai  Private Equity
# 788                   Food Logistics & Delivery       Mumbai    Seed Funding
# 789                   Tele-Shopping / eCommerce       Mumbai  Private Equity
#
#      AmountInUSD
# 0        1300000
# 1         500000
# 2         850000
# 3        1000000
# 4        2600000
# 5       20000000
# 6        8500000
# 7        1000000
# 8        1000000
# 9        3000000
# 10        464000
# 11      18500000
# 12        540000
# 13       1700000
# 14       2000000
# 15      10000000
# 16        600000
# 17        700000
# 18        200000
# 19       1200000
# 20      35000000
# 21      25000000
# 22        200000
# 23      15000000
# 24       1250000
# 25      50000000
# 26       1000000
# 27       1200000
# 28       1000000
# 29        650000
# ..           ...
# 760     10000000
# 761      5000000
# 762     10000000
# 763       100000
# 764     10000000
# 765      5000000
# 766      1300000
# 767      1300000
# 768       245000
# 769     10200000
# 770       168000
# 771       550000
# 772    137000000
# 773     50000000
# 774     10000000
# 775     16000000
# 776       500000
# 777      5500000
# 778       650000
# 779     85000000
# 780     10000000
# 781      5000000
# 782      2000000
# 783       240000
# 784     50000000
# 785       500000
# 786      3500000
# 787     18000000
# 788      1000000
# 789     21500000
#
# [790 rows x 4 columns]

# %%
industries = industries_vertical.dropna().unique()[:10]
industries_count = industries_vertical.value_counts()[:10]
plt.figure(figsize=(12,8))
sns.barplot(x=industries_count, y=industries,)
plt.ylabel('Industry Verticals')
plt.xlabel('Count')
plt.title('Top 5 industry verticals which received most funding')
# Out:
# Text(0.5,1,'Top 5 industry verticals which received most funding')

# %%
AmountInUSD = df["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))
AmountInUSD = AmountInUSD[~np.isnan(AmountInUSD)]
plt.figure(figsize=(8,6))
plt.scatter(range(len(AmountInUSD)), np.sort(AmountInUSD.values), color=color[4])
plt.xlabel('index', fontsize=12)
plt.ylabel('Funding value in USD', fontsize=12)
plt.show()
